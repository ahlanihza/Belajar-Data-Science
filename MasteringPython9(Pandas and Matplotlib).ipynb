# %%
from sklearn.impute import SimpleImputer #untuk membuat otomatisasi tanpa melakukan pemrogaman

# %%
import pandas as pd

# %%
file_path = r"D:\Personal\Learning\EXCEL\Ultimate Excel Tutorial\Data Cleaning Files\Renewebel Energy\Renewable Energy Rural Area.xlsx"

# %%
df = pd.read_excel(file_path)

# %%
df.head()
# Out:
#   Household_ID         Region    Country Energy_Source  Monthly_Usage_kWh  \
# 0       H02587      Australia  Australia    Geothermal              61001
# 1       H02654  North America        USA       Biomass             119675
# 2       H00706         Africa      Egypt         Hydro              27446
# 3       H00590         Africa      Ghana    Geothermal               5475
# 4       H02414  South America       Peru       Biomass               5717
#
#    Year  Household_Size Income_Level Urban_Rural  Adoption_Year  \
# 0  2024               4         High       Rural           2023
# 1  2024               8          Low       Rural           2017
# 2  2022               7       Middle       Rural           2010
# 3  2020               8         High       Rural           2012
# 4  2021               6          Low       Rural           2021
#
#   Subsidy_Received  Cost_Savings_USD
# 0               No              4349
# 1              Yes              9328
# ...

# %%
print(df.columns) #melihat nama column
# Out:
# Index(['Household_ID', 'Region', 'Country', 'Energy_Source',
#        'Monthly_Usage_kWh', 'Year', 'Household_Size', 'Income_Level',
#        'Urban_Rural', 'Adoption_Year', 'Subsidy_Received', 'Cost_Savings_USD'],
#       dtype='object')

# %%
df.drop(['Urban_Rural'],axis=1,inplace = True) #menghapus column

# %%
df.head()
# Out:
#   Household_ID         Region    Country Energy_Source  Monthly_Usage_kWh  \
# 0       H02587      Australia  Australia    Geothermal              61001
# 1       H02654  North America        USA       Biomass             119675
# 2       H00706         Africa      Egypt         Hydro              27446
# 3       H00590         Africa      Ghana    Geothermal               5475
# 4       H02414  South America       Peru       Biomass               5717
#
#    Year  Household_Size Income_Level  Adoption_Year Subsidy_Received  \
# 0  2024               4         High           2023               No
# 1  2024               8          Low           2017              Yes
# 2  2022               7       Middle           2010               No
# 3  2020               8         High           2012              Yes
# 4  2021               6          Low           2021              Yes
#
#    Cost_Savings_USD
# 0              4349
# 1              9328
# 2              6598
# ...

# %%
df.rename(columns={'Household_ID': 'ID','Energy_Source':'Source'},inplace=True)

# %%
df.head()
# Out:
#        ID         Region    Country      Source  Monthly_Usage_kWh  Year  \
# 0  H02587      Australia  Australia  Geothermal              61001  2024
# 1  H02654  North America        USA     Biomass             119675  2024
# 2  H00706         Africa      Egypt       Hydro              27446  2022
# 3  H00590         Africa      Ghana  Geothermal               5475  2020
# 4  H02414  South America       Peru     Biomass               5717  2021
#
#    Household_Size Income_Level  Adoption_Year Subsidy_Received  \
# 0               4         High           2023               No
# 1               8          Low           2017              Yes
# 2               7       Middle           2010               No
# 3               8         High           2012              Yes
# 4               6          Low           2021              Yes
#
#    Cost_Savings_USD
# 0              4349
# 1              9328
# 2              6598
# 3              2199
# 4              1992

# %%
df['Year'] = pd.to_datetime(df['Year']) #to convert date normal

# %%
df.head()
# Out:
#        ID         Region    Country      Source  Monthly_Usage_kWh  \
# 0  H02587      Australia  Australia  Geothermal              61001
# 1  H02654  North America        USA     Biomass             119675
# 2  H00706         Africa      Egypt       Hydro              27446
# 3  H00590         Africa      Ghana  Geothermal               5475
# 4  H02414  South America       Peru     Biomass               5717
#
#                            Year  Household_Size Income_Level  Adoption_Year  \
# 0 1970-01-01 00:00:00.000002024               4         High           2023
# 1 1970-01-01 00:00:00.000002024               8          Low           2017
# 2 1970-01-01 00:00:00.000002022               7       Middle           2010
# 3 1970-01-01 00:00:00.000002020               8         High           2012
# 4 1970-01-01 00:00:00.000002021               6          Low           2021
#
#   Subsidy_Received  Cost_Savings_USD
# 0               No              4349
# ...

# %%
df.describe()
# Out:
#        Monthly_Usage_kWh                           Year  Household_Size  \
# count         514.000000                            514      514.000000
# mean        69722.902724  1970-01-01 00:00:00.000002022        4.387160
# min           667.000000  1970-01-01 00:00:00.000002020        1.000000
# 25%         24761.500000  1970-01-01 00:00:00.000002021        2.000000
# 50%         66807.000000  1970-01-01 00:00:00.000002022        4.000000
# 75%        110828.500000  1970-01-01 00:00:00.000002023        6.000000
# max        149734.000000  1970-01-01 00:00:00.000002024        8.000000
# std         47187.061069                            NaN        2.317808
#
#        Adoption_Year  Cost_Savings_USD
# count     514.000000        514.000000
# mean     2016.033074      22913.737354
# min      2010.000000        162.000000
# 25%      2013.000000       8867.500000
# 50%      2016.000000      22461.500000
# 75%      2019.000000      35830.500000
# max      2024.000000      49931.000000
# ...

# %%
df.fillna('NA')
# Out:
#          ID         Region    Country      Source  Monthly_Usage_kWh  \
# 0    H02587      Australia  Australia  Geothermal              61001
# 1    H02654  North America        USA     Biomass             119675
# 2    H00706         Africa      Egypt       Hydro              27446
# 3    H00590         Africa      Ghana  Geothermal               5475
# 4    H02414  South America       Peru     Biomass               5717
# ..      ...            ...        ...         ...                ...
# 509  H00193  North America     Mexico  Geothermal               7269
# 510  H04232         Europe         UK  Geothermal              11747
# 511  H04425           Asia      Japan       Hydro              27215
# 512  H02314  North America        USA        Wind             118233
# 513  H03215         Europe    Germany        Wind              41788
#
#                              Year  Household_Size Income_Level  Adoption_Year  \
# ...

# %%
df.drop(['Year'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#        ID         Region    Country      Source  Monthly_Usage_kWh  \
# 0  H02587      Australia  Australia  Geothermal              61001
# 1  H02654  North America        USA     Biomass             119675
# 2  H00706         Africa      Egypt       Hydro              27446
# 3  H00590         Africa      Ghana  Geothermal               5475
# 4  H02414  South America       Peru     Biomass               5717
#
#    Household_Size Income_Level  Adoption_Year Subsidy_Received  \
# 0               4         High           2023               No
# 1               8          Low           2017              Yes
# 2               7       Middle           2010               No
# 3               8         High           2012              Yes
# 4               6          Low           2021              Yes
#
#    Cost_Savings_USD
# 0              4349
# 1              9328
# 2              6598
# 3              2199
# 4              1992

# %%
from sklearn.impute import SimpleImputer
import pandas as pd

# %%
imputer = SimpleImputer(strategy ='constant')
df2 = pd.DataFrame(imputer.fit_transform(df),columns=df.columns)

# %%
df3 = df2.groupby(['Source','Country'])[['Region','Cost_Savings_USD']].sum().reset_index()

# %%
df3.head(50)
# Out:
#         Source       Country  \
# 0      Biomass     Argentina
# 1      Biomass     Australia
# 2      Biomass        Brazil
# 3      Biomass        Canada
# 4      Biomass         Chile
# 5      Biomass      Colombia
# 6      Biomass         Egypt
# 7      Biomass        France
# 8      Biomass       Germany
# 9      Biomass         Ghana
# 10     Biomass         India
# 11     Biomass     Indonesia
# 12     Biomass         Italy
# 13     Biomass         Japan
# 14     Biomass         Kenya
# 15     Biomass        Mexico
# 16     Biomass   New Zealand
# 17     Biomass       Nigeria
# 18     Biomass          Peru
# 19     Biomass  South Africa
# 20     Biomass   South Korea
# 21     Biomass         Spain
# 22     Biomass            UK
# 23     Biomass           USA
# 24  Geothermal     Argentina
# 25  Geothermal     Australia
# 26  Geothermal        Brazil
# 27  Geothermal        Canada
# 28  Geothermal         Chile
# 29  Geothermal         China
# 30  Geothermal      Colombia
# ...

# %%
df3 = df2[df2['Cost_Savings_USD']<100000]

# %%
df3.head()
# Out:
#        ID         Region    Country      Source Monthly_Usage_kWh  \
# 0  H02587      Australia  Australia  Geothermal             61001
# 1  H02654  North America        USA     Biomass            119675
# 2  H00706         Africa      Egypt       Hydro             27446
# 3  H00590         Africa      Ghana  Geothermal              5475
# 4  H02414  South America       Peru     Biomass              5717
#
#   Household_Size Income_Level Adoption_Year Subsidy_Received Cost_Savings_USD
# 0              4         High          2023               No             4349
# 1              8          Low          2017              Yes             9328
# 2              7       Middle          2010               No             6598
# 3              8         High          2012              Yes             2199
# 4              6          Low          2021              Yes             1992

# %% [markdown]
# MATPLOTLIB

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace (0,10,100)
y = np.sin(x)
plt.plot(x,y)

# %%
plt.scatter(x[::10],y[::10],color='blue')

# %%
plt.plot(x,y,color = 'b')
plt.plot(x,np.cos(x),color ='g')
